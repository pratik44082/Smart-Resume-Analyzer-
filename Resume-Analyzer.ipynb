# %%
import pdfplumber

# %%
import faiss
import pdfplumber
import numpy as np
from openai import OpenAI

print("All imports working ✅")
# Out:
# All imports working ✅

# %%
from openai import OpenAI
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

print("Models count:", len(client.models.list().data))
